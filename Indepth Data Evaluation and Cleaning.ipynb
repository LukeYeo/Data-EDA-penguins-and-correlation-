# %% [markdown]
# Name:Yeo Chee En Luke </br>
# StudentID:46746267,S4674626 </br>
# Module:DATA2001 </br>
# Assignment:A1-Hindsight, Penguin </br>

# %% [markdown]
# # 1. Data Collection

# %% [markdown]
# ## 1.1 Loading in the dataset

# %% [markdown]
# In this file, I will be using the dataset provided by the Course : "penguin_lter.csv"

# %%
# import pandas library using alias pd
import pandas as pd

# import matpplotlib using alias pd
import matplotlib.pyplot as plt

# import numpy using alias np
import numpy as np

# load the data, rename as penguin data 
penguin_data = pd.read_csv(filepath_or_buffer='penguins_lter.csv')

# view rows of the data
penguin_data.head(344)
# Out:
#     studyName  Sample Number                              Species  Region  \
# 0     PAL0708              1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1     PAL0708              2  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 2     PAL0708              3  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 3     PAL0708              4  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 4     PAL0708              5  Adelie Penguin (Pygoscelis adeliae)  Anvers
# ..        ...            ...                                  ...     ...
# 339   PAL0910            120    Gentoo penguin (Pygoscelis papua)  Anvers
# 340   PAL0910            121    Gentoo penguin (Pygoscelis papua)  Anvers
# 341   PAL0910            122    Gentoo penguin (Pygoscelis papua)  Anvers
# 342   PAL0910            123    Gentoo penguin (Pygoscelis papua)  Anvers
# 343   PAL0910            124    Gentoo penguin (Pygoscelis papua)  Anvers
#
#         Island               Stage Individual ID Clutch Completion  \
# ...

# %% [markdown]
# ## 1.2 Column Description

# %% [markdown]
# 1.**studyName** - Sampling expedition from which data were collected, generated, etc. </br>
# 2.**Sample Number** - an integer denoting the continuous numbering sequence for each sample </br>
# 3.**Species** - a character string denoting the penguin species </br>
# 4.**Region** - a character string denoting the region of Palmer LTER sampling grid </br>
# 5.**Island** - a character string denoting the island near Palmer Station where samples were collected </br>
# 6.**Stage** - a character string denoting reproductive stage at sampling </br>
# 7.**Individual ID** - a character string denoting the unique ID for each individual in dataset </br>
# 8.**Clutch Completion** - a character string denoting if the study nest observed with a full clutch, i.e., 2 eggs </br>
# 9.**Date Egg** - a date denoting the date study nest observed with 1 egg (sampled) </br>
# 10.**Culmen Length** - a number denoting the length of the dorsal ridge of a bird's bill (millimetres) </br>
# 11.**Culmen Depth** - a number denoting the depth of the dorsal ridge of a bird's bill (millimetres) </br>
# 12.**Flipper Length** - an integer denoting the length penguin flipper (millimetres) </br>
# 13.**Body Mass** - an integer denoting the penguin body mass (grams) </br>
# 14.**Sex** - a character string denoting the sex of an animal </br>
# 15.**Delta 15 N** - a number denoting the measure of the ratio of stable isotopes 15N:14N </br>
# 16.**Delta 13 C** - a number denoting the measure of the ratio of stable isotopes 13C:12C </br>
# 17.**Comments** - a character string with text providing additional relevant information for data </br>

# %% [markdown]
# # 2. Data Preparation and Enrichment

# %% [markdown]
# Upon loading the dataset , the data needs to be examined thoroughly to check for any missing data and cleaned by imputing with justification before performing analysis. </br>
#
# These are the few steps that i have done : </br>
# - General overview of the dataset </br>
# -Checking for missing data </br>
# -Checking for duplicate data </br>
# -Imput each missing data 1 by 1 </br>
# -Justification for each type of imput

# %% [markdown]
# ### General overview of the dataset

# %%
#shape of data 
penguin_data.shape
# Out:
# (344, 17)

# %% [markdown]
# it can be seen that the database has 344 rows and 17 columns

# %%
# concise summary of the dataset
penguin_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   studyName            344 non-null    object
#  1   Sample Number        344 non-null    int64
#  2   Species              344 non-null    object
#  3   Region               344 non-null    object
#  4   Island               344 non-null    object
#  5   Stage                344 non-null    object
#  6   Individual ID        344 non-null    object
#  7   Clutch Completion    344 non-null    object
#  8   Date Egg             344 non-null    object
#  9   Culmen Length (mm)   342 non-null    float64
#  10  Culmen Depth (mm)    342 non-null    float64
#  11  Flipper Length (mm)  342 non-null    float64
#  12  Body Mass (g)        342 non-null    float64
#  13  Sex                  334 non-null    object
#  14  Delta 15 N (o/oo)    330 non-null    float64
# ...

# %% [markdown]
# ### Checking for missing data

# %%
penguin_data.isna().sum()
# Out:
# studyName                0
# Sample Number            0
# Species                  0
# Region                   0
# Island                   0
# Stage                    0
# Individual ID            0
# Clutch Completion        0
# Date Egg                 0
# Culmen Length (mm)       2
# Culmen Depth (mm)        2
# Flipper Length (mm)      2
# Body Mass (g)            2
# Sex                     10
# Delta 15 N (o/oo)       14
# Delta 13 C (o/oo)       13
# Comments               318
# dtype: int64

# %% [markdown]
# ### Checking for duplicate data

# %%
penguin_data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Observation: There are no duplicates in the dataset

# %% [markdown]
# ### Imput each data 1 by 1

# %% [markdown]
# Currently , there are missing data in the following columns :
# - 2 missing datas : Culmen Length (mm), Culmen Depth (mm), Flipper Length (mm), Body Mass (g)
# -10 missing datas : Sex
# -14 missing datas : Delta 15 N (o/oo)
# -13 missing datas : Delta 13 C (o/oo)
# -318 missing datas : Comments
#
# After knowing which data are missing, these are the steps in which i took to impute the missing data.
#
# Things i have considered while imputing the missing datas:
# 1) Ensuring the method i use is not biased which will cause inaccurate data </br>
# 2) Ensuring there is a justification to every method i use to impute the values </br>
# 3) Ensuring no assumptions of the dataset are made </br>
# 4) Ensuring that I do not fall into any pitfalls

# %% [markdown]
# <u>**- Imputing 2 missing datas**</u>

# %%
#Solving the missing datas for Culmen Length (mm), Culmen Depth (mm), Flipper Length (mm), Body Mass (g)
penguin_data = penguin_data.dropna(subset=["Culmen Length (mm)"])

# %%
penguin_data.isna().sum()
# Out:
# studyName                0
# Sample Number            0
# Species                  0
# Region                   0
# Island                   0
# Stage                    0
# Individual ID            0
# Clutch Completion        0
# Date Egg                 0
# Culmen Length (mm)       0
# Culmen Depth (mm)        0
# Flipper Length (mm)      0
# Body Mass (g)            0
# Sex                      8
# Delta 15 N (o/oo)       12
# Delta 13 C (o/oo)       11
# Comments               317
# dtype: int64

# %% [markdown]
# **Justification** :
# Looking at the row in which the missing datas are from , ive decided to drop it.
# All the missing data from in 2 rows, in which gives no numerical and gender information of the penguin which makes the 2 rows redundant as they do not provide any value to the dataset.

# %% [markdown]
# <u>**- Imputing 10 missing datas: Sex**</u>

# %%
#Check the unique values in Sex
penguin_data['Sex'].unique()
# Out:
# array(['MALE', 'FEMALE', nan, '.'], dtype=object)

# %%
#Set '.' value to "UNSPECIFIED"
Sex_replacement = {'.': "UNSPECIFIED"}
#Replace the value in the dataset
penguin_data['Sex'] = penguin_data['Sex'].replace(Sex_replacement)
#Replace the missing columns ('nan') to "Un"
penguin_data['Sex'] = penguin_data['Sex'].fillna(value ="UNSPECIFIED",)
#Check the unique values in Sex after imputs
penguin_data['Sex'].unique()
# Out:
# array(['MALE', 'FEMALE', 'UNSPECIFIED'], dtype=object)

# %%
#Check if Sex missing data has imputs
penguin_data.isna().sum()
# Out:
# studyName                0
# Sample Number            0
# Species                  0
# Region                   0
# Island                   0
# Stage                    0
# Individual ID            0
# Clutch Completion        0
# Date Egg                 0
# Culmen Length (mm)       0
# Culmen Depth (mm)        0
# Flipper Length (mm)      0
# Body Mass (g)            0
# Sex                      0
# Delta 15 N (o/oo)       12
# Delta 13 C (o/oo)       11
# Comments               317
# dtype: int64

# %%
#Check inside the database using first 20 rows
penguin_data.head(20)
# Out:
#    studyName  Sample Number                              Species  Region  \
# 0    PAL0708              1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1    PAL0708              2  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 2    PAL0708              3  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 4    PAL0708              5  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 5    PAL0708              6  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 6    PAL0708              7  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 7    PAL0708              8  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 8    PAL0708              9  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 9    PAL0708             10  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 10   PAL0708             11  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 11   PAL0708             12  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 12   PAL0708             13  Adelie Penguin (Pygoscelis adeliae)  Anvers
# ...

# %% [markdown]
# **Justification** :I have decided to make a 3rd category, "UNSPECIFIED". This is due to the fact that if I assume the penguin gender or use a random the imput by through numpy, it will cause inaccuracy in the data. Hence by categorising all the missing and '.' to a 3rd category of Sex. this will not any inconsistency, incompletetion in the dataset.

# %% [markdown]
# <u>**-Imputing 14 missing datas : Delta 15 N (o/oo)**</u>

# %%
#Create the distribution graph for Delta 15 N (o/oo)
penguin_data["Delta 15 N (o/oo)"].plot.hist(grid=False, bins=10, title="Distribution of Delta 15");

# %%
penguin_data["Delta 15 N (o/oo)"] =penguin_data["Delta 15 N (o/oo)"].fillna(value =penguin_data["Delta 15 N (o/oo)"].mean())

# %% [markdown]
# **Justification**: Upon seeing the graph, the distribution is fairly symmetrical. Hence using the Mean as the imput for the missing datas will not cause any dramatic inaccuracy or changes to the statistical value of Delta 15

# %% [markdown]
# <u>**- Imputing 13 missing datas : Delta 13 C (o/oo)**</u>

# %%
#Create the distribution graph for Delta 13 C (o/oo)
penguin_data["Delta 13 C (o/oo)"].plot.hist(grid=False, bins=10, title="Distribution of Delta 13");

# %%
penguin_data["Delta 13 C (o/oo)"] =penguin_data["Delta 13 C (o/oo)"].fillna(value =penguin_data["Delta 13 C (o/oo)"].median())

# %% [markdown]
# **Justification**: Upon seeing the graph, the distribution is not fairy symmetrical and alittle skewed. Median will be a better choice for imput as large values on the tail end of the distribution tend to pull the mean away from the center and towards the long tail. Hence using the Median as the imput for the missing datas will not cause any dramatic inaccuracy or changes to the statistical value of Delta 13

# %%
#Checking if both Delta 15 and Delta 13 missing datas has been imputed
penguin_data.isna().sum()
# Out:
# studyName                0
# Sample Number            0
# Species                  0
# Region                   0
# Island                   0
# Stage                    0
# Individual ID            0
# Clutch Completion        0
# Date Egg                 0
# Culmen Length (mm)       0
# Culmen Depth (mm)        0
# Flipper Length (mm)      0
# Body Mass (g)            0
# Sex                      0
# Delta 15 N (o/oo)        0
# Delta 13 C (o/oo)        0
# Comments               317
# dtype: int64

# %%
#Checking using the first 20 row of th data
penguin_data.head(20)
# Out:
#    studyName  Sample Number                              Species  Region  \
# 0    PAL0708              1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1    PAL0708              2  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 2    PAL0708              3  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 4    PAL0708              5  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 5    PAL0708              6  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 6    PAL0708              7  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 7    PAL0708              8  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 8    PAL0708              9  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 9    PAL0708             10  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 10   PAL0708             11  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 11   PAL0708             12  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 12   PAL0708             13  Adelie Penguin (Pygoscelis adeliae)  Anvers
# ...

# %% [markdown]
# <u>**- 318 missing datas : Comments**</u>
#
# **Justification**: I am choosing not to change/imput anything to the Comments column. This is because the Comments are more of reasoning of why the other columns values maybe empty, hence does not effect any other columns of the dataset (the penguin).

# %% [markdown]
# # 3. Exploratory Data Analysis (EDA)

# %% [markdown]
# In EDA, i will explore the data to understand its main characteristics using descriptive statistic and data visualisation.
#
# 1) Univariate EDA </br>
# 2) Bivariate EDA </br>
# 3) EDA by species - Numeric columns only

# %% [markdown]
# ## 3.1 Univariate EDA

# %% [markdown]
# ### Column 'Species'

# %%
penguin_data["Species"].describe()
# Out:
# count                                     342
# unique                                      3
# top       Adelie Penguin (Pygoscelis adeliae)
# freq                                      151
# Name: Species, dtype: object

# %%
penguin_data["Species"].unique()
# Out:
# array(['Adelie Penguin (Pygoscelis adeliae)',
#        'Chinstrap penguin (Pygoscelis antarctica)',
#        'Gentoo penguin (Pygoscelis papua)'], dtype=object)

# %%
species_distribution = penguin_data["Species"].value_counts(dropna=False, normalize=True)

# make a pie chart
species_distribution.plot.pie(autopct='%1.0f%%', pctdistance=0.8, radius=1, title="Distribution of Species");

# %% [markdown]
# Observation : There are 3 different type of species , Adelie (the most) , Gentoo , Chinstrap (the least)

# %% [markdown]
# ### Column 'Region'

# %%
penguin_data["Region"].describe()
# Out:
# count        342
# unique         1
# top       Anvers
# freq         342
# Name: Region, dtype: object

# %%
penguin_data["Region"].unique()
# Out:
# array(['Anvers'], dtype=object)

# %% [markdown]
# Observation: All the penguin comes from 1 Region , Anvers

# %% [markdown]
# ### Column 'Island'

# %%
penguin_data["Island"].describe()
# Out:
# count        342
# unique         3
# top       Biscoe
# freq         167
# Name: Island, dtype: object

# %%
penguin_data["Island"].unique()
# Out:
# array(['Torgersen', 'Biscoe', 'Dream'], dtype=object)

# %%
island_distribution = penguin_data["Island"].value_counts(dropna=False, normalize=True)

# make a pie chart
island_distribution.plot.bar(xlabel="Species", ylabel="Count of Island", grid=False, title="Distribution of Island");

# %% [markdown]
# Observation: There are 3 differnt island (Biscoe, Dream, Trogersen). Majority of the penguin comes from Biscoe, the least from Torgersen

# %% [markdown]
# ### Column 'Stage'

# %%
penguin_data["Stage"].describe()
# Out:
# count                    342
# unique                     1
# top       Adult, 1 Egg Stage
# freq                     342
# Name: Stage, dtype: object

# %%
penguin_data["Stage"].unique()
# Out:
# array(['Adult, 1 Egg Stage'], dtype=object)

# %% [markdown]
# Observation: There is only 1 stage of the penguin ('Adult, 1 Egg Stage')

# %% [markdown]
# ### Column 'Clutch Completion'

# %%
penguin_data["Clutch Completion"].describe()
# Out:
# count     342
# unique      2
# top       Yes
# freq      307
# Name: Clutch Completion, dtype: object

# %%
penguin_data["Clutch Completion"].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
clutch_distribution = penguin_data["Clutch Completion"].value_counts(dropna=False, normalize=True)

# make a pie chart
clutch_distribution.plot.pie(autopct='%1.0f%%', pctdistance=0.8, radius=1, title="Distribution of Clutch Completion");

# %% [markdown]
# Observation: Majority of the penguins are full clutch (90%)

# %% [markdown]
# ### Column 'Culmen Length (mm)'

# %%
penguin_data["Culmen Length (mm)"].describe()
# Out:
# count    342.000000
# mean      43.921930
# std        5.459584
# min       32.100000
# 25%       39.225000
# 50%       44.450000
# 75%       48.500000
# max       59.600000
# Name: Culmen Length (mm), dtype: float64

# %%
penguin_data["Culmen Length (mm)"].unique()
# Out:
# array([39.1, 39.5, 40.3, 36.7, 39.3, 38.9, 39.2, 34.1, 42. , 37.8, 41.1,
#        38.6, 34.6, 36.6, 38.7, 42.5, 34.4, 46. , 37.7, 35.9, 38.2, 38.8,
#        35.3, 40.6, 40.5, 37.9, 37.2, 40.9, 36.4, 42.2, 37.6, 39.8, 36.5,
#        40.8, 36. , 44.1, 37. , 39.6, 37.5, 42.3, 40.1, 35. , 34.5, 41.4,
#        39. , 35.7, 41.3, 41.6, 35.5, 41.8, 33.5, 39.7, 45.8, 42.8, 36.2,
#        42.1, 42.9, 35.1, 37.3, 36.3, 36.9, 38.3, 34. , 38.1, 33.1, 43.2,
#        41. , 45.6, 42.7, 40.2, 35.2, 41.5, 38.5, 43.1, 36.8, 35.6, 32.1,
#        40.7, 46.5, 50. , 51.3, 45.4, 52.7, 45.2, 46.1, 46.6, 51.7, 47. ,
#        52. , 45.9, 50.5, 50.3, 58. , 46.4, 49.2, 42.4, 48.5, 50.6, 46.7,
#        49.5, 52.8, 54.2, 51. , 49.7, 47.5, 47.6, 46.9, 53.5, 49. , 46.2,
#        50.9, 45.5, 50.8, 50.1, 51.5, 49.8, 48.1, 51.4, 45.7, 50.7, 52.2,
#        49.3, 50.2, 51.9, 46.8, 55.8, 43.5, 49.6, 48.7, 43.3, 48.4, 45.1,
#        46.3, 44.5, 47.8, 48.2, 47.3, 59.6, 49.1, 42.6, 44.4, 44. , 45.3,
# ...

# %%
penguin_data["Culmen Length (mm)"].plot.box(vert=False, title="Distribution of Culmen Length (mm)");

# %% [markdown]
# Observation: There are no outliers according to the box-plot

# %% [markdown]
# ### Column 'Culmen Depth (mm)'

# %%
penguin_data["Culmen Depth (mm)"].describe()
# Out:
# count    342.000000
# mean      17.151170
# std        1.974793
# min       13.100000
# 25%       15.600000
# 50%       17.300000
# 75%       18.700000
# max       21.500000
# Name: Culmen Depth (mm), dtype: float64

# %%
penguin_data["Culmen Depth (mm)"].unique()
# Out:
# array([18.7, 17.4, 18. , 19.3, 20.6, 17.8, 19.6, 18.1, 20.2, 17.1, 17.3,
#        17.6, 21.2, 21.1, 19. , 20.7, 18.4, 21.5, 18.3, 19.2, 17.2, 18.9,
#        18.6, 17.9, 16.7, 17. , 20. , 18.5, 19.1, 19.7, 16.9, 18.8, 17.7,
#        19.5, 17.5, 16.6, 18.2, 16.2, 19.4, 16.8, 16.1, 20.3, 16. , 16.5,
#        20.5, 19.8, 15.9, 20.1, 15.5, 19.9, 20.8, 16.4, 13.2, 16.3, 14.1,
#        15.2, 14.5, 13.5, 14.6, 15.3, 13.4, 15.4, 13.7, 15.7, 15.1, 14.3,
#        15.8, 13.1, 15. , 14.2, 14.8, 13.6, 13.9, 13.3, 14.4, 13.8, 14.9,
#        15.6, 14. , 14.7])

# %%
penguin_data["Culmen Depth (mm)"].plot.box(vert=False, title="Distribution of Culmen Depth (mm)");

# %% [markdown]
# Observation: There are no outliers according to the box-plot

# %% [markdown]
# ### Column 'Flipper Length (mm)'

# %%
penguin_data["Flipper Length (mm)"].describe()
# Out:
# count    342.000000
# mean     200.915205
# std       14.061714
# min      172.000000
# 25%      190.000000
# 50%      197.000000
# 75%      213.000000
# max      231.000000
# Name: Flipper Length (mm), dtype: float64

# %%
penguin_data["Flipper Length (mm)"].unique()
# Out:
# array([181., 186., 195., 193., 190., 180., 182., 191., 198., 185., 197.,
#        184., 194., 174., 189., 187., 183., 172., 178., 188., 196., 179.,
#        200., 192., 202., 205., 208., 203., 199., 176., 210., 201., 212.,
#        206., 207., 211., 230., 218., 215., 219., 209., 214., 216., 213.,
#        217., 221., 222., 220., 225., 224., 231., 229., 223., 228., 226.])

# %%
penguin_data["Flipper Length (mm)"].plot.box(title="Distribution of Previous Year Rating");

# %% [markdown]
# Observation: There are no outliers according to the box-plot

# %% [markdown]
# ### Column 'Body Mass (g)'

# %%
penguin_data["Body Mass (g)"].describe()
# Out:
# count     342.000000
# mean     4201.754386
# std       801.954536
# min      2700.000000
# 25%      3550.000000
# 50%      4050.000000
# 75%      4750.000000
# max      6300.000000
# Name: Body Mass (g), dtype: float64

# %%
penguin_data["Body Mass (g)"].unique()
# Out:
# array([3750., 3800., 3250., 3450., 3650., 3625., 4675., 3475., 4250.,
#        3300., 3700., 3200., 4400., 4500., 3325., 4200., 3400., 3600.,
#        3950., 3550., 3150., 3900., 4150., 4650., 3100., 3000., 4600.,
#        3425., 2975., 3500., 4300., 4050., 2900., 2850., 3350., 4100.,
#        3050., 4450., 4000., 4700., 4350., 3725., 4725., 3075., 2925.,
#        3175., 4775., 3825., 4275., 4075., 3775., 3875., 3275., 4475.,
#        3975., 3525., 3575., 4550., 3850., 4800., 2700., 3675., 5700.,
#        5400., 5200., 5150., 5550., 5850., 6300., 5350., 5000., 5050.,
#        5100., 5650., 5250., 6050., 4950., 4750., 4900., 5300., 4850.,
#        5800., 6000., 5950., 4625., 5450., 5600., 4875., 4925., 4975.,
#        5500., 4575., 4375., 5750.])

# %%
penguin_data["Body Mass (g)"].plot.box(vert=False, title="Distribution of Body Mass (g)");

# %% [markdown]
# Observation: There are no outliers according to the box-plot

# %% [markdown]
# ### Column 'Sex'

# %%
penguin_data["Sex"].describe()
# Out:
# count      342
# unique       3
# top       MALE
# freq       168
# Name: Sex, dtype: object

# %%
penguin_data["Sex"].unique()
# Out:
# array(['MALE', 'FEMALE', 'UNSPECIFIED'], dtype=object)

# %%
sex_distribution = penguin_data["Sex"].value_counts(dropna=False, normalize=True)

# make a pie chart
sex_distribution.plot.pie(autopct='%1.0f%%', pctdistance=0.8, radius=1, title="Distribution of Sex");

# %% [markdown]
# Observation: The distribution of male and female are extremely similar in the dataset (49%:48%)

# %% [markdown]
# ### Column 'Delta 15 N (o/oo)'

# %%
penguin_data["Delta 15 N (o/oo)"].describe()
# Out:
# count    342.000000
# mean       8.733382
# std        0.541975
# min        7.632200
# 25%        8.305905
# 50%        8.681410
# 75%        9.141270
# max       10.025440
# Name: Delta 15 N (o/oo), dtype: float64

# %%
penguin_data["Delta 15 N (o/oo)"].unique()
# Out:
# array([ 8.7333817,  8.94956  ,  8.36821  ,  8.76651  ,  8.66496  ,
#         9.18718  ,  9.4606   ,  9.13362  ,  8.63243  ,  8.55583  ,
#         9.18528  ,  8.67538  ,  8.47827  ,  9.11616  ,  8.73762  ,
#         8.66271  ,  9.22286  ,  8.43423  ,  9.63954  ,  9.21292  ,
#         8.93997  ,  8.08138  ,  8.38404  ,  8.90027  ,  9.69756  ,
#         9.72764  ,  9.66523  ,  8.79665  ,  9.17847  ,  9.15308  ,
#         9.18985  ,  8.04787  ,  9.41131  ,  9.68933  ,  9.50772  ,
#         9.2372   ,  9.36392  ,  9.49106  ,  9.51784  ,  8.87988  ,
#         8.46616  ,  8.51362  ,  8.19539  ,  8.48095  ,  8.41837  ,
#         8.35396  ,  8.57199  ,  8.56674  ,  9.07878  ,  9.108    ,
#         8.96472  ,  8.74802  ,  8.58063  ,  8.62264  ,  8.62623  ,
#         8.85562  ,  8.56192  ,  8.71078  ,  8.47781  ,  8.86853  ,
#         7.88863  ,  9.29808  ,  8.33524  ,  8.18658  ,  8.70642  ,
#         8.2993   ,  8.47257  ,  8.3554   ,  7.82381  ,  9.05736  ,
# ...

# %%
penguin_data["Delta 15 N (o/oo)"].plot.box(vert=False, title="Distribution of Delta 15 N (o/oo)");

# %% [markdown]
# Observation: There are no outliers according to the box-plot

# %% [markdown]
# ### Column 'Delta 13 C (o/oo)'

# %%
penguin_data["Delta 13 C (o/oo)"].describe()
# Out:
# count    342.000000
# mean     -25.691027
# std        0.781484
# min      -27.018540
# 25%      -26.295280
# 50%      -25.833520
# 75%      -25.081043
# max      -23.787670
# Name: Delta 13 C (o/oo), dtype: float64

# %%
penguin_data["Delta 13 C (o/oo)"].unique()
# Out:
# array([-25.83352, -24.69454, -25.33302, -25.32426, -25.29805, -25.21799,
#        -24.89958, -25.09368, -25.21315, -25.22588, -25.06691, -25.13993,
#        -25.23319, -24.77227, -25.09383, -25.0639 , -25.03474, -25.22664,
#        -25.29856, -24.3613 , -25.36288, -25.49448, -25.19837, -25.11609,
#        -25.11223, -25.0102 , -25.0602 , -25.14591, -25.23061, -25.03469,
#        -25.12255, -25.49523, -25.04169, -24.4228 , -25.03492, -24.52698,
#        -25.01745, -24.10255, -25.07683, -25.18543, -26.12989, -26.55602,
#        -26.17213, -26.3146 , -26.54718, -26.27853, -26.07188, -25.98843,
#        -25.88156, -25.89677, -26.40943, -26.37809, -26.21569, -26.60023,
#        -26.1165 , -26.09294, -25.95541, -25.81012, -26.07821, -26.06209,
#        -26.63085, -25.23453, -26.55351, -26.45978, -26.15003, -26.38986,
#        -26.02002, -26.44787, -26.51382, -25.81513, -26.5387 , -26.23027,
#        -26.24837, -26.46254, -26.38396, -26.09635, -26.22227, -26.08165,
# ...

# %%
penguin_data["Delta 13 C (o/oo)"].plot.box(vert=False, title="Distribution of Delta 13 C (o/oo)");

# %% [markdown]
# Observation: There are no outliers according to the box-plot

# %% [markdown]
# ## 3.2 Bivariate EDA (Numerical only)

# %%
# !pip install seaborn
import seaborn as sns

# %%
penguin_data.columns
# Out:
# Index(['studyName', 'Sample Number', 'Species', 'Region', 'Island', 'Stage',
#        'Individual ID', 'Clutch Completion', 'Date Egg', 'Culmen Length (mm)',
#        'Culmen Depth (mm)', 'Flipper Length (mm)', 'Body Mass (g)', 'Sex',
#        'Delta 15 N (o/oo)', 'Delta 13 C (o/oo)', 'Comments'],
#       dtype='object')

# %%
#For Numeric data only 
numeric_data = penguin_data[["Culmen Length (mm)", "Culmen Depth (mm)", "Flipper Length (mm)", 
                              "Body Mass (g)", "Delta 15 N (o/oo)", "Delta 13 C (o/oo)"]]

numeric_data.corr().style.background_gradient(cmap='YlOrRd')
# Out:
# <style type="text/css">
# #T_0b16e_row0_col0, #T_0b16e_row1_col1, #T_0b16e_row2_col2, #T_0b16e_row3_col3, #T_0b16e_row4_col4, #T_0b16e_row5_col5 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_0b16e_row0_col1 {
#   background-color: #fede80;
#   color: #000000;
# }
# #T_0b16e_row0_col2 {
#   background-color: #d9131f;
#   color: #f1f1f1;
# }
# #T_0b16e_row0_col3, #T_0b16e_row1_col4 {
#   background-color: #e61f1d;
#   color: #f1f1f1;
# }
# #T_0b16e_row0_col4 {
#   background-color: #fec863;
#   color: #000000;
# }
# #T_0b16e_row0_col5 {
#   background-color: #fea848;
#   color: #000000;
# }
# #T_0b16e_row1_col0, #T_0b16e_row1_col2, #T_0b16e_row2_col1, #T_0b16e_row2_col5, #T_0b16e_row3_col4, #T_0b16e_row3_col5, #T_0b16e_row4_col3 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_0b16e_row1_col3 {
#   background-color: #fffac0;
#   color: #000000;
# }
# #T_0b16e_row1_col5 {
#   background-color: #fc6631;
#   color: #f1f1f1;
# }
# #T_0b16e_row2_col0 {
# ...

# %% [markdown]
# Observation: It can be seen that there is strong positive relation between :
# 1) Culmen Length and Flipper Length </br>
# 2) Culmen Length and Body Mass </br>
# 3) Culment Depth and Delta 15 </br>
# 4) Flipper Length and Body Mass </br>
# 5) Delta 15 and Delta 13 </br>

# %% [markdown]
# ### Culmen Length and Flipper Length

# %%
penguin_data.plot(x="Culmen Length (mm)", y="Flipper Length (mm)", kind = 'scatter');

# %%
sns.scatterplot(data=penguin_data, x="Culmen Length (mm)", y="Flipper Length (mm)", hue="Species")
plt.title("Boxplot of culmen length and Flipper Length by species");

# %% [markdown]
# Observation: The points in the plot are relatively closely scattered, allowing cluster to a few group but no distinct clusters, positive linear. When seperated by Species, we can see 3 clear clusters

# %% [markdown]
# ### Culmen Length and Body Mass

# %%
penguin_data.plot(x="Culmen Length (mm)", y="Body Mass (g)", kind = 'scatter');

# %%
sns.scatterplot(data=penguin_data, x="Culmen Length (mm)", y="Body Mass (g)", hue="Species")
plt.title("Boxplot of culmen length and body mass by species");

# %% [markdown]
# Observation: The points in the plot are scattered and not easy into group/cluster, does seem like there would be positive correlation , positive linear graph . When seperated by species, we can see 3 distinct clusters

# %% [markdown]
# ### Culment Depth and Delta 15

# %%
penguin_data.plot(x="Culmen Depth (mm)", y="Delta 15 N (o/oo)", kind = 'scatter');

# %%
sns.scatterplot(data=penguin_data, x="Culmen Depth (mm)", y="Delta 15 N (o/oo)", hue="Species")
plt.title("Boxplot of culmen depth and delta15 by species");

# %% [markdown]
# Observation: The points in the plot are extremely scattered and not easy into group/cluster, seems like there would be no correlation . When seperated by species, we can see 1 unique cluster for Gentoo but a mix for Adelie and Chinstrap

# %% [markdown]
# ### Flipper Length and Body Mass

# %%
penguin_data.plot(x="Flipper Length (mm)", y="Body Mass (g)", kind = 'scatter');

# %%
sns.scatterplot(data=penguin_data, x="Flipper Length (mm)", y="Body Mass (g)", hue="Species")
plt.title("Boxplot of flipper length and body mass by species");

# %% [markdown]
# Observation: The points in the plot are relatively closely scattered, allowing cluster to a few group, positive linear graph and does seem like there would be positive correlation. When seperated by species, we can see 1 unique cluster for Gentoo but a mix for Adelie and Chinstrap

# %% [markdown]
# ### Delta 15 and Delta 13

# %%
penguin_data.plot(x="Delta 15 N (o/oo)", y="Delta 13 C (o/oo)", kind = 'scatter');

# %%
sns.scatterplot(data=penguin_data, x="Delta 15 N (o/oo)", y="Delta 13 C (o/oo)", hue="Species")
plt.title("Boxplot of delta 15 and delta 13 by species");

# %% [markdown]
# Observation: The points in the plot are extremely scattered and not easy into group/cluster, does not seem like there would be a correlation . When seperated by species, there we can see 3 clusters, though not extremely distinct (some overlaps)

# %% [markdown]
# ## 3.3 EDA by species (mean and standard deviation)

# %% [markdown]
# ### Culmen Length by species

# %%
Species_Culmen_Length = penguin_data.groupby('Species')["Culmen Length (mm)"].describe()
print(Species_Culmen_Length)
# Out:
#                                            count       mean       std   min  \
# Species
# Adelie Penguin (Pygoscelis adeliae)        151.0  38.791391  2.663405  32.1
# Chinstrap penguin (Pygoscelis antarctica)   68.0  48.833824  3.339256  40.9
# Gentoo penguin (Pygoscelis papua)          123.0  47.504878  3.081857  40.9
#
#                                              25%    50%     75%   max
# Species
# Adelie Penguin (Pygoscelis adeliae)        36.75  38.80  40.750  46.0
# Chinstrap penguin (Pygoscelis antarctica)  46.35  49.55  51.075  58.0
# Gentoo penguin (Pygoscelis papua)          45.30  47.30  49.550  59.6

# %%
pd.DataFrame(Species_Culmen_Length, columns=["mean","std"])
# Out:
#                                                 mean       std
# Species
# Adelie Penguin (Pygoscelis adeliae)        38.791391  2.663405
# Chinstrap penguin (Pygoscelis antarctica)  48.833824  3.339256
# Gentoo penguin (Pygoscelis papua)          47.504878  3.081857

# %% [markdown]
# Observation: Comparing the 3 different species culmen length ,the std for all 3 penguins species are close to each other (value diff is around 0.4). However for the mean, the mean of Adelie Penguin (Pygoscelis adeliae)	is far at 38.7+ as compared to the
# Chinstrap penguin (Pygoscelis antarctica) and Gentoo penguin (Pygoscelis papua)

# %% [markdown]
# ### Culmen Depth by species

# %%
Species_Culmen_Depth= penguin_data.groupby('Species')["Culmen Depth (mm)"].describe()
print(Species_Culmen_Depth)
# Out:
#                                            count       mean       std   min  \
# Species
# Adelie Penguin (Pygoscelis adeliae)        151.0  18.346358  1.216650  15.5
# Chinstrap penguin (Pygoscelis antarctica)   68.0  18.420588  1.135395  16.4
# Gentoo penguin (Pygoscelis papua)          123.0  14.982114  0.981220  13.1
#
#                                             25%    50%   75%   max
# Species
# Adelie Penguin (Pygoscelis adeliae)        17.5  18.40  19.0  21.5
# Chinstrap penguin (Pygoscelis antarctica)  17.5  18.45  19.4  20.8
# Gentoo penguin (Pygoscelis papua)          14.2  15.00  15.7  17.3

# %%
pd.DataFrame(Species_Culmen_Depth, columns=["mean","std"])
# Out:
#                                                 mean       std
# Species
# Adelie Penguin (Pygoscelis adeliae)        18.346358  1.216650
# Chinstrap penguin (Pygoscelis antarctica)  18.420588  1.135395
# Gentoo penguin (Pygoscelis papua)          14.982114  0.981220

# %% [markdown]
# Observation: Comparing the 3 different species culmen depth,the mean for Adelie Penguin (Pygoscelis adeliae) and Chinstrap penguin (Pygoscelis antarctica) are close to each other (around 18+) while the mean for gentoo is quite far (14.9+) . The standard deviation among the 3 species culmen depth are close to each other

# %% [markdown]
# ### Flipper Length by species

# %%
Species_Flipper_Length= penguin_data.groupby('Species')["Flipper Length (mm)"].describe()
print(Species_Flipper_Length)
# Out:
#                                            count        mean       std    min  \
# Species
# Adelie Penguin (Pygoscelis adeliae)        151.0  189.953642  6.539457  172.0
# Chinstrap penguin (Pygoscelis antarctica)   68.0  195.823529  7.131894  178.0
# Gentoo penguin (Pygoscelis papua)          123.0  217.186992  6.484976  203.0
#
#                                              25%    50%    75%    max
# Species
# Adelie Penguin (Pygoscelis adeliae)        186.0  190.0  195.0  210.0
# Chinstrap penguin (Pygoscelis antarctica)  191.0  196.0  201.0  212.0
# Gentoo penguin (Pygoscelis papua)          212.0  216.0  221.0  231.0

# %%
pd.DataFrame(Species_Flipper_Length, columns=["mean","std"])
# Out:
#                                                  mean       std
# Species
# Adelie Penguin (Pygoscelis adeliae)        189.953642  6.539457
# Chinstrap penguin (Pygoscelis antarctica)  195.823529  7.131894
# Gentoo penguin (Pygoscelis papua)          217.186992  6.484976

# %% [markdown]
# Observation:Comparing the 3 different species flipper length, the standard deviation of Adelie Penguin (Pygoscelis adeliae) and Gentoo penguin (Pygoscelis papua) are close to each other

# %% [markdown]
# ### Body Mass by species

# %%
Species_Body_Mass= penguin_data.groupby('Species')["Body Mass (g)"].describe()
print(Species_Body_Mass)
# Out:
#                                            count         mean         std  \
# Species
# Adelie Penguin (Pygoscelis adeliae)        151.0  3700.662252  458.566126
# Chinstrap penguin (Pygoscelis antarctica)   68.0  3733.088235  384.335081
# Gentoo penguin (Pygoscelis papua)          123.0  5076.016260  504.116237
#
#                                               min     25%     50%     75%  \
# Species
# Adelie Penguin (Pygoscelis adeliae)        2850.0  3350.0  3700.0  4000.0
# Chinstrap penguin (Pygoscelis antarctica)  2700.0  3487.5  3700.0  3950.0
# Gentoo penguin (Pygoscelis papua)          3950.0  4700.0  5000.0  5500.0
#
#                                               max
# Species
# Adelie Penguin (Pygoscelis adeliae)        4775.0
# Chinstrap penguin (Pygoscelis antarctica)  4800.0
# Gentoo penguin (Pygoscelis papua)          6300.0

# %%
pd.DataFrame(Species_Body_Mass, columns=["mean","std"])
# Out:
#                                                   mean         std
# Species
# Adelie Penguin (Pygoscelis adeliae)        3700.662252  458.566126
# Chinstrap penguin (Pygoscelis antarctica)  3733.088235  384.335081
# Gentoo penguin (Pygoscelis papua)          5076.016260  504.116237

# %% [markdown]
# Observation:Comparing the 3 different species body mass, the mean of Adelie Penguin (Pygoscelis adeliae) and Chinstrap penguin (Pygoscelis antarctica) are close to each other but the mean of Gentoo penguin (Pygoscelis papua) is higher value

# %% [markdown]
# ### Delta 15 N (o/oo) by species

# %%
Species_Delta15= penguin_data.groupby('Species')["Delta 15 N (o/oo)"].describe()
print(Species_Delta15)
# Out:
#                                            count      mean       std      min  \
# Species
# Adelie Penguin (Pygoscelis adeliae)        151.0  8.851365  0.412969  7.69778
# Chinstrap penguin (Pygoscelis antarctica)   68.0  9.346996  0.373670  8.47173
# Gentoo penguin (Pygoscelis papua)          123.0  8.249306  0.267035  7.63220
#
#                                                 25%      50%       75%  \
# Species
# Adelie Penguin (Pygoscelis adeliae)        8.576310  8.85562  9.124890
# Chinstrap penguin (Pygoscelis antarctica)  9.082998  9.37084  9.618898
# Gentoo penguin (Pygoscelis papua)          8.103240  8.25540  8.436185
#
#                                                 max
# Species
# Adelie Penguin (Pygoscelis adeliae)         9.79532
# Chinstrap penguin (Pygoscelis antarctica)  10.02544
# Gentoo penguin (Pygoscelis papua)           8.83352

# %%
pd.DataFrame(Species_Delta15, columns=["mean","std"])
# Out:
#                                                mean       std
# Species
# Adelie Penguin (Pygoscelis adeliae)        8.851365  0.412969
# Chinstrap penguin (Pygoscelis antarctica)  9.346996  0.373670
# Gentoo penguin (Pygoscelis papua)          8.249306  0.267035

# %% [markdown]
# Observation: Comparing the 3 different species delta 15 N (o/oo) , each species mean and standard deviation are almost equally apart (mean different rounding: 0.6, standard deviation different rounding: 0.1)

# %% [markdown]
# ### Delta 13 C (o/oo) by species

# %%
Species_Delta13= penguin_data.groupby('Species')["Delta 13 C (o/oo)"].describe()
print(Species_Delta13)
# Out:
#                                            count       mean       std  \
# Species
# Adelie Penguin (Pygoscelis adeliae)        151.0 -25.806136  0.568289
# Chinstrap penguin (Pygoscelis antarctica)   68.0 -24.546542  0.238809
# Gentoo penguin (Pygoscelis papua)          123.0 -26.182438  0.537279
#
#                                                 min        25%        50%  \
# Species
# Adelie Penguin (Pygoscelis adeliae)       -26.78958 -26.218980 -25.887980
# Chinstrap penguin (Pygoscelis antarctica) -25.14550 -24.685153 -24.572375
# Gentoo penguin (Pygoscelis papua)         -27.01854 -26.690165 -26.216510
#
#                                                  75%       max
# Species
# Adelie Penguin (Pygoscelis adeliae)       -25.328640 -23.90309
# Chinstrap penguin (Pygoscelis antarctica) -24.400333 -23.78767
# Gentoo penguin (Pygoscelis papua)         -25.654140 -25.00169

# %%
pd.DataFrame(Species_Delta13, columns=["mean","std"])
# Out:
#                                                 mean       std
# Species
# Adelie Penguin (Pygoscelis adeliae)       -25.806136  0.568289
# Chinstrap penguin (Pygoscelis antarctica) -24.546542  0.238809
# Gentoo penguin (Pygoscelis papua)         -26.182438  0.537279

# %% [markdown]
# Observation: Comparing the 3 different species delta 13 C (o/oo), the standard deviation of Adelie Penguin (Pygoscelis adeliae) and Gentoo penguin (Pygoscelis papua) are close to each other

# %% [markdown]
# # 4. Correlations

# %% [markdown]
# **Covariance**
#
# It represents how two variables/columns/attributes are related. Higher values indicates higher dependency/relation between them. Values ranges from -ve infinity to +ve infinity. +ve values indicates direct relation (increase in x value will have increase in y value) and -ve value shows inverse relation (increase in x value will have decrease in y value).

# %%
penguin_data.groupby('Species').cov()
# Out:
# C:\R\ipykernel_14104\1246733136.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.cov is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   penguin_data.groupby('Species').cov()
#                                                                Sample Number  \
# Species
# Adelie Penguin (Pygoscelis adeliae)       Sample Number          1915.646269
#                                           Culmen Length (mm)        1.149828
#                                           Culmen Depth (mm)       -12.767073
#                                           Flipper Length (mm)      91.185740
#                                           Body Mass (g)          -589.653422
#                                           Delta 15 N (o/oo)         1.510907
#                                           Delta 13 C (o/oo)       -11.894039
# ...

# %% [markdown]
# <u>**Correlation**</u>
#
# It represents the strength of the relation and it is standardized, values ranges between -1 to +1. Variables are strongly correlated when the value is close to +ve 1 (positive correlation) or -ve 1 (negative correlation). 0 indicates no relation among them.

# %% [markdown]
# **Pearason Correlation Coefficient (Pearson r):**
#
# It measures the linear relation among the variables. Given by ratio of the covariance of x and y to the product of their standard deviations. https://en.wikipedia.org/wiki/Correlation

# %%
penguin_data.groupby('Species').corr().style.background_gradient(cmap='Reds')
# Out:
# C:\R\ipykernel_14104\3529252103.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.corr is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   penguin_data.groupby('Species').corr().style.background_gradient(cmap='Reds')
# <style type="text/css">
# #T_5fadc_row0_col0, #T_5fadc_row1_col1, #T_5fadc_row2_col2, #T_5fadc_row3_col3, #T_5fadc_row4_col4, #T_5fadc_row5_col5, #T_5fadc_row6_col6, #T_5fadc_row7_col0, #T_5fadc_row8_col1, #T_5fadc_row9_col2, #T_5fadc_row10_col3, #T_5fadc_row11_col4, #T_5fadc_row12_col5, #T_5fadc_row13_col6, #T_5fadc_row14_col0, #T_5fadc_row15_col1, #T_5fadc_row16_col2, #T_5fadc_row17_col3, #T_5fadc_row18_col4, #T_5fadc_row19_col5, #T_5fadc_row20_col6 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# ...

# %% [markdown]
# **Spearman Correlation Coefficient (Spearman rho):**
#
# It measures the monotonic relation (non-linear relation).
# Same as pearson but uses ranked values instead of original values.
# https://en.wikipedia.org/wiki/Spearman%27s_rank_correlation_coefficient

# %%
penguin_data.groupby('Species').corr(method = 'spearman').style.background_gradient(cmap='Reds')
# Out:
# C:\R\ipykernel_14104\1709002668.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.corr is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   penguin_data.groupby('Species').corr(method = 'spearman').style.background_gradient(cmap='Reds')
# <style type="text/css">
# #T_e732c_row0_col0, #T_e732c_row1_col1, #T_e732c_row2_col2, #T_e732c_row3_col3, #T_e732c_row4_col4, #T_e732c_row5_col5, #T_e732c_row6_col6, #T_e732c_row7_col0, #T_e732c_row8_col1, #T_e732c_row9_col2, #T_e732c_row10_col3, #T_e732c_row11_col4, #T_e732c_row12_col5, #T_e732c_row13_col6, #T_e732c_row14_col0, #T_e732c_row15_col1, #T_e732c_row16_col2, #T_e732c_row17_col3, #T_e732c_row18_col4, #T_e732c_row19_col5, #T_e732c_row20_col6 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_e732c_row0_col1 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# ...

# %% [markdown]
# **Kendall Correlation Coefficient (Kendall tau):**
#
# It measures the monotonic relation (non-linear relation). Similar to spearman based on ranked values and uses pair of observations to determine its relation. It is more robust and benifitical to use when there is a outliers in the data.
# https://en.wikipedia.org/wiki/Spearman%27s_rank_correlation_coefficient

# %%
penguin_data.groupby('Species').corr(method = 'kendall').style.background_gradient(cmap='Reds')
# Out:
# C:\R\ipykernel_14104\3267872079.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.corr is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   penguin_data.groupby('Species').corr(method = 'kendall').style.background_gradient(cmap='Reds')
# <style type="text/css">
# #T_032ae_row0_col0, #T_032ae_row1_col1, #T_032ae_row2_col2, #T_032ae_row3_col3, #T_032ae_row4_col4, #T_032ae_row5_col5, #T_032ae_row6_col6, #T_032ae_row7_col0, #T_032ae_row8_col1, #T_032ae_row9_col2, #T_032ae_row10_col3, #T_032ae_row11_col4, #T_032ae_row12_col5, #T_032ae_row13_col6, #T_032ae_row14_col0, #T_032ae_row15_col1, #T_032ae_row16_col2, #T_032ae_row17_col3, #T_032ae_row18_col4, #T_032ae_row19_col5, #T_032ae_row20_col6 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# ...

# %% [markdown]
# Observations: </br>
# weak: values < 0.25 </br>
# moderate: 0.25 < values < 0.75 </br>
# strong: values > 0.75 </br>
#
# 1) Culmen Length and Flipper Length </br>
# There is a moderate correlation between Culmen Length and Flipper Length (within all 3 species, all 3 values are close to 0.5).
#
# 2) Culmen Length and Body Mass </br>
# There is a moderate coorelation between Culmen Length and Body Mass (within all 3 species,  all 3 values are close to 0.5)
#
# 3) Culment Depth and Delta 15 </br>
# There is weak coorelation between  Culment Depth and Delta 15 (within all 3 species, all 3 values are less than 0.25)
#
# 4) Flipper Length and Body Mass </br>
# There is a moderate correlation between Flipper Length and Body Mass (within all 3 species, all 3 values are close to 0.5), this correlation is the strongest among the 5 other relations
#
# 5) Delta 15 and Delta 13 </br>
# There is a weak correlation between Delta 15 and Delta 13 (within all 3 species, all 3 values are close to 0.5)

# %% [markdown]
# # 5. K-mean clustering

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import minmax_scale

# %% [markdown]
# ## 1) Culmen Length and Flipper Length

# %%
data_to_clfl = penguin_data.loc[:344, ["Culmen Length (mm)" ,"Flipper Length (mm)"]]
sns.pairplot(data_to_clfl);

# %%
# scale the data using minmax scale
scaled_data = minmax_scale(data_to_clfl)

# initialize KMeans object with number of desired clusters
k_means = KMeans(n_clusters=3)

# fit and transform k_means object to scaled data
k_means.fit_transform(scaled_data)

# extract cluster labels
data_to_clfl["cluster_labels"] = k_means.labels_

# plot the clusters
sns.scatterplot(data=data_to_clfl, x="Culmen Length (mm)", y="Flipper Length (mm)", hue="cluster_labels")
plt.title("K-means graph for culmen lenngth and flipper length");
# Out:
# C:\Users\Luke Yeo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# Observation: After trying out K being 3-6, i have chosen K to be 4 as the cluster and repeat till the graph does not change. ,The graph matches with the graph in EDA after. The limitation of K is 6.

# %% [markdown]
# ## 2) Culmen Length and Body Mass

# %%
data_to_clbm = penguin_data.loc[:344, ["Culmen Length (mm)" ,"Body Mass (g)"]]
sns.pairplot(data_to_clbm);

# %%
# scale the data using minmax scale
scaled_data = minmax_scale(data_to_clbm)

# initialize KMeans object with number of desired clusters
k_means = KMeans(n_clusters=3)

# fit and transform k_means object to scaled data
k_means.fit_transform(scaled_data)

# extract cluster labels
data_to_clbm["cluster_labels"] = k_means.labels_

# plot the clusters
sns.scatterplot(data=data_to_clbm, x="Culmen Length (mm)", y="Body Mass (g)", hue="cluster_labels")
plt.title("K-means graph for culmen length and body mass");
# Out:
# C:\Users\Luke Yeo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# Observation: After trying out K being 3-6, i have chosen K to be 5 as the cluster and repeat till the graph does not change. ,The graph do match with EDA graph.

# %% [markdown]
# ## 3) Culment Depth and Delta 15

# %%
data_to_cdd = penguin_data.loc[:344, ["Culmen Depth (mm)" ,"Delta 15 N (o/oo)"]]
sns.pairplot(data_to_cdd);

# %%
# scale the data using minmax scale
scaled_data = minmax_scale(data_to_cdd)

# initialize KMeans object with number of desired clusters
k_means = KMeans(n_clusters=4)

# fit and transform k_means object to scaled data
k_means.fit_transform(scaled_data)

# extract cluster labels
data_to_cdd["cluster_labels"] = k_means.labels_

# plot the clusters
sns.scatterplot(data=data_to_cdd, x="Culmen Depth (mm)", y="Delta 15 N (o/oo)", hue="cluster_labels")
plt.title("K-means graph for culmen depth and delta 15");
# Out:
# C:\Users\Luke Yeo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# Observation: After trying out K being 3-6, i have chosen K to be 4 as the cluster and repeat till the graph does not change. ,The graph do match with EDA

# %% [markdown]
# ## 4) Flipper Length and Body Mass

# %%
data_to_flbm = penguin_data.loc[:344, ["Flipper Length (mm)" ,"Body Mass (g)"]]
sns.pairplot(data_to_flbm);

# %%
# scale the data using minmax scale
scaled_data = minmax_scale(data_to_flbm)

# initialize KMeans object with number of desired clusters
k_means = KMeans(n_clusters=3)

# fit and transform k_means object to scaled data
k_means.fit_transform(scaled_data)

# extract cluster labels
data_to_flbm["cluster_labels"] = k_means.labels_

# plot the clusters
sns.scatterplot(data=data_to_flbm, x="Flipper Length (mm)", y="Body Mass (g)", hue="cluster_labels")
plt.title("K-means graph for culmen depth and delta 15");
# Out:
# C:\Users\Luke Yeo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# Observation: After trying out K being 3-6, i have chosen K to be 5 as the cluster and repeat till the graph does not change. ,The graph do match with EDA

# %% [markdown]
# ## 5) Delta 15 and Delta 13

# %%
data_to_deltas = penguin_data.loc[:344, ["Delta 15 N (o/oo)" ,"Delta 13 C (o/oo)"]]
sns.pairplot(data_to_deltas);

# %%
# scale the data using minmax scale
scaled_data = minmax_scale(data_to_deltas)

# initialize KMeans object with number of desired clusters
k_means = KMeans(n_clusters=4)

# fit and transform k_means object to scaled data
k_means.fit_transform(scaled_data)

# extract cluster labels
data_to_deltas["cluster_labels"] = k_means.labels_

# plot the clusters
sns.scatterplot(data=data_to_deltas, x="Delta 15 N (o/oo)", y="Delta 13 C (o/oo)", hue="cluster_labels")
plt.title("K-means graph for delta 15 and delta 13");
# Out:
# C:\Users\Luke Yeo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# Observation: After trying out K being 3-6, i have chosen K to be 6 as the cluster and repeat till the graph does not change. ,The graph do match with EDA

# %% [markdown]
# # 6. Principal component analysis

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

#format all numerical columns together
numerical = ['Culmen Length (mm)','Culmen Depth (mm)', 'Flipper Length (mm)', 'Body Mass (g)', 'Delta 15 N (o/oo)', 'Delta 13 C (o/oo)']

# seperate x and y by numerical columns and non-numerical
x = penguin_data.loc[:, numerical].values
y = penguin_data.loc[:, ['Species', 'Region', 'Island', 'Clutch Completion', 'Sex']].values
x = StandardScaler().fit_transform(x)

# %%
pca = PCA(n_components=5)
pcaComponents = pca.fit_transform(x)
pcaDataframe = pd.DataFrame(data = pcaComponents)

# %%
targetDataframe = penguin_data[['Species', 'Region', 'Island', 'Clutch Completion', 'Sex']]

newDataframe = pd.concat([pcaDataframe, targetDataframe],axis = 1)

# %%
percent_variance = np.round(pca.explained_variance_ratio_* 100, decimals =2)
columns = ['PC1', 'PC2', 'PC3','PC4', 'PC5']
plt.bar(x= range(1,6), height=percent_variance, tick_label=columns)
plt.ylabel('Percentate of Variance Explained')
plt.xlabel('Principal Component')
plt.title('PCA Scree Plot')
plt.show()

# %% [markdown]
# Observation : after playing around till having PC5, the difference between PC3,PC4 and PC5 does not change much. Hence we will use up to PC3 s it is a good tradeoff between having lower dimensional space with few dimensions but also a good amount of cumulative variance.

# %%
pca = PCA(n_components=3)
pcaComponents = pca.fit_transform(x)
pcaDataframe = pd.DataFrame(data = pcaComponents,columns = ['PC1', 'PC2','PC3'])

# %%
percent_variance = np.round(pca.explained_variance_ratio_* 100, decimals =2)
columns = ['PC1', 'PC2', 'PC3']
plt.bar(x= range(1,4), height=percent_variance, tick_label=columns)
plt.ylabel('Percentate of Variance Explained')
plt.xlabel('pcaComponent')
plt.title('PCA Plot')
plt.show()

# %% [markdown]
# Observation: in total of PC1 , PC2 , PC3 covers approximately 85% of the variance of the original dataset.

# %%
plt.scatter(pcaDataframe.PC1, pcaDataframe.PC2)
plt.title('PC1 against PC2')
plt.xlabel('PC1')
plt.ylabel('PC2')
# Out:
# Text(0, 0.5, 'PC2')

# %%
plt.scatter(pcaDataframe.PC2, pcaDataframe.PC3)
plt.title('PC2 against PC3')
plt.xlabel('PC2')
plt.ylabel('PC3')
# Out:
# Text(0, 0.5, 'PC3')

# %%
plt.scatter(pcaDataframe.PC1, pcaDataframe.PC3)
plt.title('PC1 against PC3')
plt.xlabel('PC1')
plt.ylabel('PC3')
# Out:
# Text(0, 0.5, 'PC3')

# %% [markdown]
# Observation:
#
# - PC1 and PC2 </br>
# When looking at the group between PC1 and PC2, there is 2 distinct clustering  group
#
# - PC3 and PC2 </br>
# When looking at the group between PC3 and PC2, the points are extremely scattered, making it hard to form distinct cluster groups.
#
# - PC1 and PC3 </br>
# When looking at the group between PC1 and PC3, there is 2 distinct clustering  group
